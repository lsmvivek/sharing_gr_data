# %%
import numpy as np
import matplotlib.pyplot as plt
import proplot
from matplotlib import cm
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pandas as pd
import seaborn as sns

# %%
temp_dataframe = pd.read_csv('/home/caliber/research/cauvery_basin_twsa.csv', sep='\t')
temp_dataframe.set_index('time', inplace=True)
temp_dataframe
# Out:
#                  TWSA
# time
# 2002-01-31        NaN
# 2002-02-28        NaN
# 2002-03-31        NaN
# 2002-04-30 -10.451692
# 2002-05-31 -12.149652
# ...               ...
# 2023-08-31        NaN
# 2023-09-30        NaN
# 2023-10-31        NaN
# 2023-11-30        NaN
# 2023-12-31        NaN
#
# [264 rows x 1 columns]

# %%
# Set the style and color palette
# sns.set(style="darkgrid", palette="colorblind")

# Create the plot
fig, ax = plt.subplots(figsize=(12, 6))
temp_dataframe.plot(ax=ax)

# # Add vertical lines for each year
# for year in np.arange(0, 264, 12):
#     ax.axvline(year, color='gray', linestyle='--', alpha=0.5)
ax.set_xlabel('')
ax.set_ylabel('TWSA change in cm')

# Set the title
ax.set_title('Cauvery Basin TWSA')

# Set the aspect ratio
ax.set_aspect('auto')
plt.savefig('/home/caliber/research/cauvery_basin_twsa.png', dpi=300, bbox_inches='tight')
# Show the plot
plt.show()

# %%
np.arange(0, 264, 12)
# Out:
# array([  0,  12,  24,  36,  48,  60,  72,  84,  96, 108, 120, 132, 144,
#        156, 168, 180, 192, 204, 216, 228, 240, 252])
